# %% [markdown]
# # CLEANING DATABASE

# %%
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Reading csv

# %%
df_match_20082009 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2008-to-2009-stats.csv')
df_match_20092010 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2009-to-2010-stats.csv')
df_match_20102011 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2010-to-2011-stats.csv')
df_match_20112012 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2011-to-2012-stats.csv')
df_match_20122013 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2012-to-2013-stats.csv')
df_match_20132014 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2013-to-2014-stats.csv')
df_match_20142015 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2014-to-2015-stats.csv')
df_match_20152016 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2015-to-2016-stats.csv')
df_match_20162017 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2016-to-2017-stats.csv')
df_match_20172018 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2017-to-2018-stats.csv')
df_match_20182019 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2018-to-2019-stats.csv')
df_match_20192020 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2019-to-2020-stats.csv')
df_match_20202021 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2020-to-2021-stats.csv')
df_match_20212022 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2021-to-2022-stats.csv')
df_match_20222023 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2022-to-2023-stats.csv')
df_match_20232024 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2023-to-2024-stats.csv')
df_match_20242025 = pd.read_csv('../../initial/Footystats/spain-la-liga-matches-2024-to-2025-stats.csv')

df_bets_20082009 = pd.read_csv('../../initial/Bets/20082009.csv')
df_bets_20092010 = pd.read_csv('../../initial/Bets/20092010.csv')
df_bets_20102011 = pd.read_csv('../../initial/Bets/20102011.csv')
df_bets_20112012 = pd.read_csv('../../initial/Bets/20112012.csv')
df_bets_20122013 = pd.read_csv('../../initial/Bets/20122013.csv')
df_bets_20132014 = pd.read_csv('../../initial/Bets/20132014.csv')
df_bets_20142015 = pd.read_csv('../../initial/Bets/20142015.csv')
df_bets_20152016 = pd.read_csv('../../initial/Bets/20152016.csv')
df_bets_20162017 = pd.read_csv('../../initial/Bets/20162017.csv')
df_bets_20172018 = pd.read_csv('../../initial/Bets/20172018.csv')
df_bets_20182019 = pd.read_csv('../../initial/Bets/20182019.csv')
df_bets_20192020 = pd.read_csv('../../initial/Bets/20192020.csv')
df_bets_20202021 = pd.read_csv('../../initial/Bets/20202021.csv')
df_bets_20212022 = pd.read_csv('../../initial/Bets/20212022.csv')
df_bets_20222023 = pd.read_csv('../../initial/Bets/20222023.csv')
df_bets_20232024 = pd.read_csv('../../initial/Bets/20232024.csv')
df_bets_20242025 = pd.read_csv('../../initial/Bets/20242025.csv')

# %% [markdown]
# #### Match ID

# %%
dataframes = [
    df_match_20082009, df_match_20092010, df_match_20102011, df_match_20112012, 
    df_match_20122013, df_match_20132014, df_match_20142015, df_match_20152016, 
    df_match_20162017, df_match_20172018, df_match_20182019, df_match_20192020, 
    df_match_20202021, df_match_20212022, df_match_20222023, df_match_20232024, 
    df_match_20242025
]

match_id_counter = 1

for df in dataframes:
    df['match_id'] = range(match_id_counter, match_id_counter + len(df))
    match_id_counter = df['match_id'].iloc[-1] + 1

# %% [markdown]
# ### Merging dataset

# %%
team_names = {
    'Espanol': 'RCD Espanyol',
    'Valencia': 'Valencia CF',
    'Ath Bilbao': 'Athletic Club Bilbao',
    'Ath Madrid': 'Atlético Madrid',
    'Betis': 'Real Betis',
    'La Coruna': 'Deportivo La Coruña',
    'Numancia': 'CD Numancia',
    'Osasuna': 'CA Osasuna',
    'Santander': 'Racing Santander',
    'Sp Gijon': 'Sporting Gijón',
    'Barcelona': 'FC Barcelona',
    'Valladolid': 'Real Valladolid',
    'Almeria': 'Almería',
    'Getafe': 'Getafe CF',
    'Malaga': 'Málaga CF',
    'Mallorca': 'RCD Mallorca',
    'Real Madrid': 'Real Madrid',
    'Recreativo': 'Recreativo de Huelva',
    'Sevilla': 'Sevilla FC',
    'Villarreal': 'Villarreal',
    'Tenerife': 'CD Tenerife',
    'Zaragoza': 'Real Zaragoza',
    'Xerez': 'Xerez CD',
    'Hercules': 'Hércules CF',
    'Levante': 'Levante UD',
    'Sociedad': 'Real Sociedad',
    'Granada': 'Granada CF',
    'Vallecano': 'Rayo Vallecano',
    'Sociedad': 'Real Sociedad',
    'Celta': 'Celta de Vigo',
    'Elche': 'Elche CF',
    'Eibar': 'SD Eibar',
    'Cordoba': 'Córdoba',
    'Las Palmas': 'UD Las Palmas',
    'Alaves': 'Deportivo Alavés',
    'Girona': 'Girona FC',
    'Huesca': 'SD Huesca',
    'Leganes': 'Leganés',
    'Cadiz': 'Cádiz'
}

df_bets_20082009['HomeTeam'] = df_bets_20082009['HomeTeam'].replace(team_names)
df_bets_20082009['AwayTeam'] = df_bets_20082009['AwayTeam'].replace(team_names)

df_match_20082009 = pd.merge(df_match_20082009, df_bets_20082009, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20092010['HomeTeam'] = df_bets_20092010['HomeTeam'].replace(team_names)
df_bets_20092010['AwayTeam'] = df_bets_20092010['AwayTeam'].replace(team_names)

df_match_20092010 = pd.merge(df_match_20092010, df_bets_20092010, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20102011['HomeTeam'] = df_bets_20102011['HomeTeam'].replace(team_names)
df_bets_20102011['AwayTeam'] = df_bets_20102011['AwayTeam'].replace(team_names)

df_match_20102011 = pd.merge(df_match_20102011, df_bets_20102011, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20112012['HomeTeam'] = df_bets_20112012['HomeTeam'].replace(team_names)
df_bets_20112012['AwayTeam'] = df_bets_20112012['AwayTeam'].replace(team_names)

df_match_20112012 = pd.merge(df_match_20112012, df_bets_20112012, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20122013['HomeTeam'] = df_bets_20122013['HomeTeam'].replace(team_names)
df_bets_20122013['AwayTeam'] = df_bets_20122013['AwayTeam'].replace(team_names)

df_match_20122013 = pd.merge(df_match_20122013, df_bets_20122013, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20132014['HomeTeam'] = df_bets_20132014['HomeTeam'].replace(team_names)
df_bets_20132014['AwayTeam'] = df_bets_20132014['AwayTeam'].replace(team_names)

df_match_20132014 = pd.merge(df_match_20132014, df_bets_20132014, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20142015['HomeTeam'] = df_bets_20142015['HomeTeam'].replace(team_names)
df_bets_20142015['AwayTeam'] = df_bets_20142015['AwayTeam'].replace(team_names)

df_match_20142015 = pd.merge(df_match_20142015, df_bets_20142015, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20152016['HomeTeam'] = df_bets_20152016['HomeTeam'].replace(team_names)
df_bets_20152016['AwayTeam'] = df_bets_20152016['AwayTeam'].replace(team_names)

df_match_20152016 = pd.merge(df_match_20152016, df_bets_20152016, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20162017['HomeTeam'] = df_bets_20162017['HomeTeam'].replace(team_names)
df_bets_20162017['AwayTeam'] = df_bets_20162017['AwayTeam'].replace(team_names)

df_match_20162017 = pd.merge(df_match_20162017, df_bets_20162017, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20172018['HomeTeam'] = df_bets_20172018['HomeTeam'].replace(team_names)
df_bets_20172018['AwayTeam'] = df_bets_20172018['AwayTeam'].replace(team_names)

df_match_20172018 = pd.merge(df_match_20172018, df_bets_20172018, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20182019['HomeTeam'] = df_bets_20182019['HomeTeam'].replace(team_names)
df_bets_20182019['AwayTeam'] = df_bets_20182019['AwayTeam'].replace(team_names)

df_match_20182019 = pd.merge(df_match_20182019, df_bets_20182019, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20192020['HomeTeam'] = df_bets_20192020['HomeTeam'].replace(team_names)
df_bets_20192020['AwayTeam'] = df_bets_20192020['AwayTeam'].replace(team_names)

df_match_20192020 = pd.merge(df_match_20192020, df_bets_20192020, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20202021['HomeTeam'] = df_bets_20202021['HomeTeam'].replace(team_names)
df_bets_20202021['AwayTeam'] = df_bets_20202021['AwayTeam'].replace(team_names)

df_match_20202021 = pd.merge(df_match_20202021, df_bets_20202021, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20212022['HomeTeam'] = df_bets_20212022['HomeTeam'].replace(team_names)
df_bets_20212022['AwayTeam'] = df_bets_20212022['AwayTeam'].replace(team_names)

df_match_20212022 = pd.merge(df_match_20212022, df_bets_20212022, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20222023['HomeTeam'] = df_bets_20222023['HomeTeam'].replace(team_names)
df_bets_20222023['AwayTeam'] = df_bets_20222023['AwayTeam'].replace(team_names)

df_match_20222023 = pd.merge(df_match_20222023, df_bets_20222023, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20232024['HomeTeam'] = df_bets_20232024['HomeTeam'].replace(team_names)
df_bets_20232024['AwayTeam'] = df_bets_20232024['AwayTeam'].replace(team_names)

df_match_20232024 = pd.merge(df_match_20232024, df_bets_20232024, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

df_bets_20242025['HomeTeam'] = df_bets_20242025['HomeTeam'].replace(team_names)
df_bets_20242025['AwayTeam'] = df_bets_20242025['AwayTeam'].replace(team_names)

df_match_20242025 = pd.merge(df_match_20242025, df_bets_20242025, left_on=['home_team_name', 'away_team_name'], right_on=['HomeTeam', 'AwayTeam'], how='inner')

# %%
df_list = [
    df_match_20082009,
    df_match_20092010,
    df_match_20102011,
    df_match_20112012,
    df_match_20122013,
    df_match_20132014,
    df_match_20142015,
    df_match_20152016,
    df_match_20162017,
    df_match_20172018,
    df_match_20182019,
    df_match_20192020,
    df_match_20202021,
    df_match_20212022,
    df_match_20222023,
    df_match_20232024,
    df_match_20242025
]

df_match_since_2008 = pd.concat(df_list, ignore_index=True)

df_match_since_2008 = df_match_since_2008.sort_values(by='timestamp', ascending=True)

# %%
df_match_since_2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6239 entries, 0 to 6238
# Columns: 231 entries, timestamp to BFECAHA
# dtypes: float64(163), int64(53), object(15)
# memory usage: 11.0+ MB

# %%
df_match_since_2008.tail()
# Out:
#        timestamp              date_GMT    status  attendance  \
# 6234  1733662800  Dec 08 2024 - 1:00pm  complete     11312.0
# 6235  1733670900  Dec 08 2024 - 3:15pm  complete     47203.0
# 6236  1733679000  Dec 08 2024 - 5:30pm  complete         NaN
# 6237  1733688000  Dec 08 2024 - 8:00pm  complete     60065.0
# 6238  1733774400  Dec 09 2024 - 8:00pm  complete         NaN
#
#             home_team_name    away_team_name                 referee  \
# 6234               Leganés     Real Sociedad  Pablo González Fuertes
# 6235  Athletic Club Bilbao        Villarreal   Víctor García Verdura
# 6236            CA Osasuna  Deportivo Alavés        César Soto Grado
# 6237       Atlético Madrid        Sevilla FC   Javier Alberola Rojas
# 6238             Getafe CF      RCD Espanyol   Mateo Busquets Ferrer
#
#       Game Week  Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  \
# 6234        NaN                  1.43                  1.57      1.25
# ...

# %% [markdown]
# #### Cleaning columns

# %%
df_match_since_2008 = df_match_since_2008.drop(columns=['HomeTeam', 'AwayTeam' ,'Div', 'Date', 'FTHG', 
'FTAG', 'HTHG', 'HTAG', 'HTR', 'HY', 'AY', 'HR', 'AR' ,'team_a_xg', 'team_b_xg', 'Away Team Pre-Match xG', 
'Home Team Pre-Match xG', 'away_team_possession', 'home_team_possession', 'home_team_shots', 'away_team_shots', 
'home_team_shots_on_target', 'away_team_shots_on_target', 'home_team_fouls', 'away_team_fouls', 
'home_team_corner_count', 'away_team_corner_count', 'odds_ft_over15', 'odds_ft_over25', 
'odds_ft_over35', 'odds_ft_over45', 'odds_btts_yes', 'odds_btts_no', 'odds_ft_home_team_win', 
'odds_ft_draw','odds_ft_away_team_win', 'status'])

# %%
df_match_since_2008 = df_match_since_2008.rename(columns={'HS': 'home_team_shots'})
df_match_since_2008 = df_match_since_2008.rename(columns={'AS': 'away_team_shots'})
df_match_since_2008 = df_match_since_2008.rename(columns={'HST': 'home_team_shots_on_target'})
df_match_since_2008 = df_match_since_2008.rename(columns={'AST': 'away_team_shots_on_target'})
df_match_since_2008 = df_match_since_2008.rename(columns={'HF': 'home_team_fouls'})
df_match_since_2008 = df_match_since_2008.rename(columns={'AF': 'away_team_fouls'})
df_match_since_2008 = df_match_since_2008.rename(columns={'HC': 'home_team_corner_count'})
df_match_since_2008 = df_match_since_2008.rename(columns={'AC': 'away_team_corner_count'})

# %%
df_match_since_2008.head()
# Out:
#     timestamp              date_GMT  attendance    home_team_name  \
# 0  1220119200  Aug 30 2008 - 6:00pm     19350.0      RCD Espanyol
# 1  1220126400  Aug 30 2008 - 8:00pm     40000.0       Valencia CF
# 6  1220202000  Aug 31 2008 - 5:00pm     18161.0  Racing Santander
# 3  1220202000  Aug 31 2008 - 5:00pm     50000.0   Atlético Madrid
# 8  1220202000  Aug 31 2008 - 5:00pm     18000.0        CA Osasuna
#
#     away_team_name                    referee  Game Week  \
# 0  Real Valladolid    Miguel Ángel Ayza Gámez        1.0
# 1     RCD Mallorca                        NaN        1.0
# 6       Sevilla FC   Alberto Undiano Mallenco        1.0
# 3        Málaga CF  Julian Rodriguez Santiago        1.0
# 8       Villarreal  Alfonso Álvarez Izquierdo        1.0
#
#    Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_ppg  away_ppg  \
# 0                   0.0                   0.0      1.53      0.74
# 1                   0.0                   0.0      2.11      0.95
# ...

# %% [markdown]
# #### Dropping and adding columns % attendance

# %%
df_match_since_2008['home_team_name'].value_counts()
# Out:
# home_team_name
# Athletic Club Bilbao    314
# Atlético Madrid         312
# Sevilla FC              312
# Real Madrid             312
# Valencia CF             311
# FC Barcelona            310
# Getafe CF               294
# Villarreal              292
# Real Sociedad           274
# RCD Espanyol            273
# Real Betis              255
# Celta de Vigo           237
# CA Osasuna              237
# Levante UD              209
# Granada CF              190
# Málaga CF               190
# RCD Mallorca            180
# Rayo Vallecano          178
# Real Valladolid         160
# Deportivo La Coruña     152
# Deportivo Alavés        140
# Almería                 133
# SD Eibar                133
# Sporting Gijón          114
# Elche CF                 95
# Girona FC                84
# Leganés                  84
# UD Las Palmas            84
# Racing Santander         76
# Real Zaragoza            76
# Cádiz                    76
# SD Huesca                38
# ...

# %%
df_match_since_2008['stadium_name'].value_counts()
# Out:
# stadium_name
# Estadio Ramón Sánchez Pizjuán (Sevilla)                                  312
# Estadio de Mestalla (Valencia)                                           310
# Coliseum Alfonso Pérez (Getafe)                                          292
# Estadio de la Cerámica (Villarreal)                                      289
# Estadio Santiago Bernabéu (Madrid)                                       287
# Spotify Camp Nou (Barcelona)                                             285
# Reale Arena (Donostia-San Sebastián)                                     273
# RCDE Stadium (Cornella de Llobregat)                                     254
# Estadio Benito Villamarín (Sevilla)                                      253
# Estadio Abanca-Balaídos (Vigo)                                           236
# Estadio El Sadar (Pamplona (Iruñea))                                     236
# San Mamés Barria (Bilbao)                                                216
# ...

# %%
stadium_names = {
    'Estadio Ramón Sánchez Pizjuán': 'Estadio Ramón Sánchez Pizjuán (Sevilla)',
    'RCDE Stadium': 'RCDE Stadium (Cornella de Llobregat)',
    'Estadio de Mestalla': 'Estadio de Mestalla (Valencia)',
    'Estadio Santiago Bernabéu': 'Estadio Santiago Bernabéu (Madrid)',
    'Camp Nou': 'Spotify Camp Nou (Barcelona)',
    'Camp Nou (Barcelona)': 'Spotify Camp Nou (Barcelona)',
    'Estadio de la Cerámica': 'Estadio de la Cerámica (Villarreal)',
    'Estadio del Rayo Vallecano (de Vallecas Teresa Rivero) (Madrid)': 'Estadio de Vallecas (Madrid)',
    'Estadio de Balaídos (Vigo)': 'Estadio Abanca-Balaídos (Vigo)',
    'Abanca-Balaídos (Vigo)': 'Estadio Abanca-Balaídos (Vigo)',
    'Power Horse Stadium - Estadio de los Juegos Mediterráneos (Almería)': 'Estadio de los Juegos Mediterráneos (Almería)',
    'Power Horse Stadium (Almería)': 'Estadio de los Juegos Mediterráneos (Almería)',
    'Estadio Wanda Metropolitano (Madrid)': 'Riyadh Air Metropolitano (Madrid)',
    'Estadio Ciudad de Valencia': 'Estadio Ciudad de Valencia (Valencia)',
    'Stage Front Stadium (Cornella de Llobregat)': 'RCDE Stadium (Cornella de Llobregat)',
    'Estadio El Sadar': 'Estadio El Sadar (Pamplona (Iruñea))',
    'Estadio Coliseum (Getafe)': 'Coliseum Alfonso Pérez (Getafe)',
    'Coliseum Alfonso Pérez': 'Coliseum Alfonso Pérez (Getafe)',
    'Estadio Municipal de Anoeta': 'Reale Arena (Donostia-San Sebastián)',
    'San Mamés Barria': 'San Mamés Barria (Bilbao)',
    'Iberostar Estadi': 'Iberostar Estadi (Palma de Mallorca)',
    'Estádio Cívitas Metropolitano (Madrid)': 'Riyadh Air Metropolitano (Madrid)',
    'Estadio Municipal de Riazor (A Coruña (La Coruña))': 'Estadio Abanca-Riazor (A Coruña (La Coruña))',
    'Estadio Municipal de Ipurúa': 'Estadio Municipal de Ipurúa (Eibar)',
    'Estadio Ramón de Carranza (Cádiz)': 'Estadio Nuevo Mirandilla (Cádiz)',
    'Estadio Manuel Martínez Valero': 'Estadio Manuel Martínez Valero (Elche)',
    'Estadio de Gran Canaria (Las Palmas de Gran Canaria)': 'Estadio de Gran Canaria (Las Palmas)',
    'Visit Mallorca Estadi (Palma de Mallorca)': 'Iberostar Estadi (Palma de Mallorca)',
    'Estadi Mallorca Son Moix (Palma de Mallorca)': 'Iberostar Estadi (Palma de Mallorca)',
    'Estadi Municipal de Montilivi': 'Estadi Municipal de Montilivi (Girona)',
    'Estadio Nuevo Arcángel': 'Estadio Nuevo Arcángel (Cordoba)',
    'Estadio Municipal de Anoeta (San Sebastián)': 'Reale Arena (Donostia-San Sebastián)'
}

df_match_since_2008['stadium_name'] = df_match_since_2008['stadium_name'].replace(stadium_names)

# %%
conditions = [
    (df_match_since_2008['stadium_name'] == 'Estadi Olímpic Lluís Companys (Barcelona)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de Mestalla (Valencia)'),
    (df_match_since_2008['stadium_name'] == 'Estadio San Mamés (old) (Bilbao)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Vicente Calderón (Madrid)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Benito Villamarín (Sevilla)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Municipal El Molinón (Gijón)'),
    (df_match_since_2008['stadium_name'] == 'Campos de Sport de El Sardinero (Santander)'),
    (df_match_since_2008['stadium_name'] == 'Nuevo Estadio Los Pajaritos (Soria)'),
    (df_match_since_2008['stadium_name'] == 'Estadio El Sadar (Pamplona (Iruñea))'),
    (df_match_since_2008['stadium_name'] == 'Estadio Municipal José Zorrilla (Valladolid)'),
    (df_match_since_2008['stadium_name'] == 'Spotify Camp Nou (Barcelona)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Ramón Sánchez Pizjuán (Sevilla)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Nuevo Colombino (Huelva)'),
    (df_match_since_2008['stadium_name'] == 'Coliseum Alfonso Pérez (Getafe)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de la Cerámica (Villarreal)'),
    (df_match_since_2008['stadium_name'] == 'Iberostar Estadi (Palma de Mallorca)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Santiago Bernabéu (Madrid)'),
    (df_match_since_2008['stadium_name'] == 'RCDE Stadium (Cornella de Llobregat)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Abanca-Balaídos (Vigo)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de Vallecas (Madrid)'),
    (df_match_since_2008['stadium_name'] == 'Reale Arena (Donostia-San Sebastián)'),
    (df_match_since_2008['stadium_name'] == 'San Mamés Barria (Bilbao)'),
    (df_match_since_2008['stadium_name'] == 'Estadio La Rosaleda (Málaga)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de Mendizorroza (Vitoria-Gasteiz)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Nuevo Los Cármenes (Granada)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Ciudad de Valencia (Valencia)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Municipal de Ipurúa (Eibar)'),
    (df_match_since_2008['stadium_name'] == 'Estadi Municipal de Montilivi (Girona)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Abanca-Riazor (A Coruña (La Coruña))'),
    (df_match_since_2008['stadium_name'] == 'Estadio Nuevo Mirandilla (Cádiz)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de la Romareda (Zaragoza)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Manuel Martínez Valero (Elche)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Municipal de Butarque (Leganés)'),
    (df_match_since_2008['stadium_name'] == 'Estadio El Alcoraz (Huesca)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de los Juegos Mediterráneos (Almería)'),
    (df_match_since_2008['stadium_name'] == 'Estadio de Gran Canaria (Las Palmas de Gran Canaria)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Alfredo Di Stéfano (Madrid)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Heliodoro Rodríguez Lopéz (Santa Cruz de Tenerife (Tenerife))'),
    (df_match_since_2008['stadium_name'] == 'Estadio Nuevo Arcángel (Córdoba)'),
    (df_match_since_2008['stadium_name'] == 'Estadio Camilo Cano (La Nucía)'),
    (df_match_since_2008['stadium_name'] == 'Riyadh Air Metropolitano (Madrid)')
]

values = [
    56000, 
    55500, 
    40000, 
    55000, 
    52000, 
    24000, 
    22000, 
    9500, 
    20000, 
    34000, 
    27000, 
    99000, 
    45500, 
    28963, 
    20000, 
    15000, 
    23000, 
    23000, 
    80000, 
    22000,
    40000
]

df_match_since_2008['capacity'] = np.select(conditions, values)

# %%
df_match_since_2008['attendance%'] = df_match_since_2008['attendance']/df_match_since_2008['capacity']

# %%
df_match_since_2008 = df_match_since_2008.drop(['status', 'stadium_name', 'attendance', 'capacity'], axis=1)

# %%
df_match_since_2008.head()

# %% [markdown]
# #### Working on referees

# %%
df2_match_20082009['referee'] = df2_match_20082009['referee'].astype(str)

# %%
df2_match_20082009['referee'].value_counts()

# %%
match_ids_with_null_referee = df2_match_20082009['match_id'][df2_match_20082009['referee'] == 'nan'].tolist()
print(match_ids_with_null_referee)

# %%
conditions = [
    (df2_match_20082009['match_id'] == 2),
    (df2_match_20082009['match_id'] == 5),
    (df2_match_20082009['match_id'] == 6),
    (df2_match_20082009['match_id'] == 12),
    (df2_match_20082009['match_id'] == 16),
    (df2_match_20082009['match_id'] == 17),
    (df2_match_20082009['match_id'] == 18),
    (df2_match_20082009['match_id'] == 23),
    (df2_match_20082009['match_id'] == 24),
    (df2_match_20082009['match_id'] == 25),
    (df2_match_20082009['match_id'] == 30),
    (df2_match_20082009['match_id'] == 31),
    (df2_match_20082009['match_id'] == 32),
    (df2_match_20082009['match_id'] == 33),
    (df2_match_20082009['match_id'] == 39),
    (df2_match_20082009['match_id'] == 44),
    (df2_match_20082009['match_id'] == 50),
    (df2_match_20082009['match_id'] == 52),
    (df2_match_20082009['match_id'] == 56),
    (df2_match_20082009['match_id'] == 57),
    (df2_match_20082009['match_id'] == 60),
    (df2_match_20082009['match_id'] == 64),
    (df2_match_20082009['match_id'] == 68),
    (df2_match_20082009['match_id'] == 70),
    (df2_match_20082009['match_id'] == 72),
    (df2_match_20082009['match_id'] == 73),
    (df2_match_20082009['match_id'] == 74),
    (df2_match_20082009['match_id'] == 84),
    (df2_match_20082009['match_id'] == 85),
    (df2_match_20082009['match_id'] == 88),
    (df2_match_20082009['match_id'] == 91),
    (df2_match_20082009['match_id'] == 95),
    (df2_match_20082009['match_id'] == 96),
    (df2_match_20082009['match_id'] == 98),
    (df2_match_20082009['match_id'] == 99),
    (df2_match_20082009['match_id'] == 104),
    (df2_match_20082009['match_id'] == 105),
    (df2_match_20082009['match_id'] == 107),
    (df2_match_20082009['match_id'] == 114),
    (df2_match_20082009['match_id'] == 115),
    (df2_match_20082009['match_id'] == 116),
    (df2_match_20082009['match_id'] == 120),
    (df2_match_20082009['match_id'] == 121),
    (df2_match_20082009['match_id'] == 126),
    (df2_match_20082009['match_id'] == 132),
    (df2_match_20082009['match_id'] == 134),
    (df2_match_20082009['match_id'] == 138),
    (df2_match_20082009['match_id'] == 141),
    (df2_match_20082009['match_id'] == 144),
    (df2_match_20082009['match_id'] == 148),
    (df2_match_20082009['match_id'] == 149),
    (df2_match_20082009['match_id'] == 151),
    (df2_match_20082009['match_id'] == 155),
    (df2_match_20082009['match_id'] == 157),
    (df2_match_20082009['match_id'] == 163),
    (df2_match_20082009['match_id'] == 165),
    (df2_match_20082009['match_id'] == 166),
    (df2_match_20082009['match_id'] == 168),
    (df2_match_20082009['match_id'] == 171),
    (df2_match_20082009['match_id'] == 177),
    (df2_match_20082009['match_id'] == 183),
    (df2_match_20082009['match_id'] == 184),
    (df2_match_20082009['match_id'] == 187),
    (df2_match_20082009['match_id'] == 189),
    (df2_match_20082009['match_id'] == 196),
    (df2_match_20082009['match_id'] == 197),
    (df2_match_20082009['match_id'] == 198),
    (df2_match_20082009['match_id'] == 209),
    (df2_match_20082009['match_id'] == 210),
    (df2_match_20082009['match_id'] == 215),
    (df2_match_20082009['match_id'] == 219),
    (df2_match_20082009['match_id'] == 221),
    (df2_match_20082009['match_id'] == 222),
    (df2_match_20082009['match_id'] == 229),
    (df2_match_20082009['match_id'] == 230),
    (df2_match_20082009['match_id'] == 235),
    (df2_match_20082009['match_id'] == 240),
    (df2_match_20082009['match_id'] == 242),
    (df2_match_20082009['match_id'] == 243),
    (df2_match_20082009['match_id'] == 244),
    (df2_match_20082009['match_id'] == 246),
    (df2_match_20082009['match_id'] == 247),
    (df2_match_20082009['match_id'] == 259),
    (df2_match_20082009['match_id'] == 266),
    (df2_match_20082009['match_id'] == 269),
    (df2_match_20082009['match_id'] == 270),
    (df2_match_20082009['match_id'] == 272),
    (df2_match_20082009['match_id'] == 273),
    (df2_match_20082009['match_id'] == 280),
    (df2_match_20082009['match_id'] == 284),
    (df2_match_20082009['match_id'] == 290),
    (df2_match_20082009['match_id'] == 291),
    (df2_match_20082009['match_id'] == 292),
    (df2_match_20082009['match_id'] == 293),
    (df2_match_20082009['match_id'] == 296),
    (df2_match_20082009['match_id'] == 301),
    (df2_match_20082009['match_id'] == 306),
    (df2_match_20082009['match_id'] == 308),
    (df2_match_20082009['match_id'] == 314),
    (df2_match_20082009['match_id'] == 316),
    (df2_match_20082009['match_id'] == 324),
    (df2_match_20082009['match_id'] == 329),
    (df2_match_20082009['match_id'] == 330),
    (df2_match_20082009['match_id'] == 332),
    (df2_match_20082009['match_id'] == 342),
    (df2_match_20082009['match_id'] == 343),
    (df2_match_20082009['match_id'] == 348),
    (df2_match_20082009['match_id'] == 355),
    (df2_match_20082009['match_id'] == 358),
    (df2_match_20082009['match_id'] == 359),
    (df2_match_20082009['match_id'] == 360),
    (df2_match_20082009['match_id'] == 362),
    (df2_match_20082009['match_id'] == 364),
    (df2_match_20082009['match_id'] == 369),
    (df2_match_20082009['match_id'] == 379),
    (df2_match_20082009['match_id'] == 380)
]

values = [
    'Antonio Rubinos Pérez', 
    'Carlos Megía Dávila', 
    'Alfonso Pérez Burrull', 
    'Rafael Ramírez Domínguez', 
    'Eduardo Iturralde González', 
    'Arturo Daudén Ibánez', 
    'Javier Turienzo Álvarez', 
    'Mejuto González', 
    'Antonio Rubinos Pérez', 
    'Alfonso Pérez Burrull', 
    'Carlos Megía Dávila', 
    'Arturo Daudén Ibánez', 
    'Eduardo Iturralde González', 
    'Rafael Ramírez Domínguez', 
    'Javier Turienzo Álvarez', 
    'Carlos Megía Dávila', 
    'Mejuto González', 
    'Eduardo Iturralde González', 
    'Rafael Ramírez Domínguez',
    'Antonio Rubinos Pérez', 
    'Alfonso Pérez Burrull',
    'Javier Turienzo Álvarez', 
    'Carlos Megía Dávila',
    'Arturo Daudén Ibánez', 
    'Alfonso Pérez Burrull',
    'Eduardo Iturralde González', 
    'Rafael Ramírez Domínguez',
    'Javier Turienzo Álvarez', 
    'Arturo Daudén Ibánez',
    'Antonio Rubinos Pérez', 
    'Eduardo Iturralde González',
    'Alfonso Pérez Burrull', 
    'Rafael Ramírez Domínguez',
    'Carlos Megía Dávila', 
    'Mejuto González',
    'Antonio Rubinos Pérez', 
    'Javier Turienzo Álvarez',
    'Arturo Daudén Ibánez', 
    'Alfonso Pérez Burrull',
    'Carlos Megía Dávila', 
    'Rafael Ramírez Domínguez',
    'Mejuto González', 
    'Alfonso Pérez Burrull',
    'Eduardo Iturralde González', 
    'Javier Turienzo Álvarez',
    'Antonio Rubinos Pérez', 
    'Rafael Ramírez Domínguez',
    'Eduardo Iturralde González', 
    'Mejuto González',
    'Alfonso Pérez Burrull', 
    'Carlos Megía Dávila',
    'Rafael Ramírez Domínguez', 
    'Javier Turienzo Álvarez',
    'Antonio Rubinos Pérez', 
    'Carlos Megía Dávila',
    'Mejuto González', 
    'Alfonso Pérez Burrull',
    'Eduardo Iturralde González', 
    'Antonio Rubinos Pérez',
    'Javier Turienzo Álvarez', 
    'Rafael Ramírez Domínguez',
    'Alfonso Pérez Burrull', 
    'Mejuto González',
    'Carlos Megía Dávila', 
    'Antonio Rubinos Pérez',
    'Javier Turienzo Álvarez', 
    'Eduardo Iturralde González',
    'Mejuto González', 
    'Carlos Megía Dávila',
    'Mejuto González',
    'Antonio Rubinos Pérez', 
    'Eduardo Iturralde González',
    'Carlos Megía Dávila', 
    'Javier Turienzo Álvarez',
    'Rafael Ramírez Domínguez', 
    'Carlos Megía Dávila',
    'Alfonso Pérez Burrull', 
    'Mejuto González',
    'Antonio Rubinos Pérez', 
    'Javier Turienzo Álvarez',
    'Eduardo Iturralde González', 
    'Rafael Ramírez Domínguez',
    'Antonio Rubinos Pérez',
    'Antonio Rubinos Pérez', 
    'Eduardo Iturralde González',
    'Mejuto González', 
    'Eduardo Iturralde González',
    'Mejuto González', 
    'Rafael Ramírez Domínguez',
    'Mejuto González', 
    'Rafael Ramírez Domínguez',
    'Eduardo Iturralde González', 
    'Antonio Rubinos Pérez',
    'Rafael Ramírez Domínguez', 
    'Mejuto González',
    'Javier Turienzo Álvarez',
    'Alfonso Pérez Burrull', 
    'Antonio Rubinos Pérez',
    'Eduardo Iturralde González', 
    'Mejuto González',
    'Rafael Ramírez Domínguez', 
    'Alfonso Pérez Burrull',
    'Javier Turienzo Álvarez', 
    'Eduardo Iturralde González',
    'Mejuto González', 
    'Eduardo Iturralde González',
    'Alfonso Pérez Burrull', 
    'Antonio Rubinos Pérez',
    'Rafael Ramírez Domínguez', 
    'Eduardo Iturralde González',
    'Mejuto González', 
    'Antonio Rubinos Pérez',
    'Eduardo Iturralde González', 
    'Alfonso Pérez Burrull',
    'Eduardo Iturralde González', 
    'Alfonso Pérez Burrull'
]

values = np.array([str(value) for value in values], dtype=object)

temp_referee = np.select(conditions, values, default=df2_match_20082009['referee'])

df2_match_20082009['referee'] = temp_referee

# %%
df2_match_20082009[['date_GMT', 'home_team_name', 'away_team_name']][df2_match_20082009['referee'].isnull()]

# %%
df2_match_20082009['referee'].value_counts()

# %%
df2_match_20082009.head()

# %% [markdown]
# #### Working on shots

# %%
df2_match_20082009['home_team_shots'].value_counts()

# %%
df2_match_20082009['away_team_shots'].value_counts()

# %%
df2_match_20082009['home_team_shots_on_target'].value_counts()

# %%
df2_match_20082009['away_team_shots_on_target'].value_counts()

# %%
df2_match_20082009['home_team_shots_off_target'].value_counts()

# %%
df2_match_20082009['away_team_shots_off_target'].value_counts()

# %%
df2_match_20082009['home_team_shots_off_target'] = df2_match_20082009['home_team_shots'] - df2_match_20082009['home_team_shots_off_target']
df2_match_20082009['away_team_shots_off_target'] = df2_match_20082009['away_team_shots'] - df2_match_20082009['away_team_shots_on_target']

# %%
df2_match_20082009['home_team_shots_off_target'].value_counts()

# %%
df2_match_20082009['away_team_shots_off_target'].value_counts()

# %%
df2_match_20082009.head()
