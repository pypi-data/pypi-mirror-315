# %% [markdown]
# # LLMs

# %%
from esperanto import OpenAILanguageModel, XAILanguageModel, OpenRouterLanguageModel, AnthropicLanguageModel, OllamaLanguageModel, GeminiLanguageModel

messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What's the capital of France?"},
    ]


params = {
    "max_tokens": 850,
    "temperature": 1.0,
    "streaming": False,
    "top_p": 0.9,
    "structured": None
}

models = {
    "openrouter": {"class": OpenRouterLanguageModel, "model": "mistralai/mistral-large-2411"},
    "openai": {"class": OpenAILanguageModel, "model": "gpt-4o"},
    "xai": {"class": XAILanguageModel, "model": "grok-beta"},
    "anthropic": {"class": AnthropicLanguageModel, "model": "claude-3-opus-20240229"},
    "ollama": {"class": OllamaLanguageModel, "model": "gemma2"},
    "gemini": {"class": GeminiLanguageModel, "model": "gemini-2.0-flash-exp"},

}

# %% [markdown]
# ## Chat Completion

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(messages)
    print(result.choices[0].message.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France. If you have any other questions about France or anything else, feel free to ask!
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# Paris is located in the north-central part of the country and is the most populous city in France. It is situated on the River Seine and is a major global center for art, fashion, gastronomy, and culture. Paris is home to many famous landmarks, including the Eiffel Tower, the Louvre Museum, Notre-Dame Cathedral, and the Champs-Élysées. The city has been the French capital since the 12th century and is also an important hub for business, politics, and transportation in Europe.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**. 🇫🇷  😊
#
#
# ==================================================
#
# Results for gemini:
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = await llm.achat_complete(messages)
    print(result.choices[0].message.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# Paris is located in the north-central part of the country and is the most populous city in France. It is situated on the River Seine and is a major cultural, commercial, fashion, and tourist hub renowned for its architecture, museums, cuisine, and monuments like the Eiffel Tower, Notre-Dame Cathedral, and the Louvre Museum. Paris has been the French capital since the 12th century and is also the seat of the French government.
#
# ==================================================
#
# Results for ollama:
# The capital of France is Paris.  🗼🇫🇷
#
#
# ==================================================
#
# Results for gemini:
# The capital of France is Paris.
#
# ==================================================

# %% [markdown]
# ### JSON

# %%
import json

json_messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Please return the top 3 brazilian cities in JSON format"},
    ]


for name, config in models.items():
    llm = config["class"](model_name=config["model"], structured="json")
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(json_messages)
    try:
        json_data = json.loads(result.choices[0].message.content)
        print(json_data)
    except json.JSONDecodeError:
        print("Error decoding JSON")
    
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# Error decoding JSON
#
# ==================================================
#
# Results for openai:
# {'cities': [{'name': 'São Paulo', 'population': 12300000, 'state': 'São Paulo'}, {'name': 'Rio de Janeiro', 'population': 6748000, 'state': 'Rio de Janeiro'}, {'name': 'Brasília', 'population': 3055000, 'state': 'Distrito Federal'}]}
#
# ==================================================
#
# 2024-12-14 20:56:38 | esperanto | WARNING | Structured output not supported for X.AI.
# Results for xai:
# Error decoding JSON
#
# ==================================================
#
# Results for anthropic:
# 2024-12-14 20:56:41 | esperanto | WARNING | Structured output not supported for Anthropic.
# Error decoding JSON
#
# ==================================================
#
# Results for ollama:
# {'top_3_brazilian_cities': [{'city': 'São Paulo', 'population': '12,470,000'}, {'city': 'Rio de Janeiro', 'population': '6,800,000'}, {'city': 'Brasília', 'population': '3,100,000'}]}
#
# ==================================================
#
# Results for gemini:
# {'top_cities': [{'rank': '1', 'city': 'São Paulo'}, {'rank': '2', 'city': 'Rio de Janeiro'}, {'rank': '3', 'city': 'Brasília'}]}
#
# ==================================================

# %% [markdown]
# ## Streaming

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(
        messages, stream=True
    )

    for chunk in result:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' known', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' for', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' icon', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'ic', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' land', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'marks', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' like', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' E', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'iff', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'el', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Tower', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Lou', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'vre', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Museum', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Not', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 're', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'D', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'ame', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' Cat', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 'hedral', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' also', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' largest', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' city', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' in', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220612-dh2NHHV9GjDkYYLtbzzZ', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220612, object='chat.completion.chunk')
#
# ==================================================
#
# Results for openai:
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': '.', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWIBtQhv5xNp3tREXnogXALfSwbT', choices=[StreamChoice(index=0, delta={'content': None, 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='gpt-4o-2024-08-06', created=1734220615, object='chat.completion.chunk')
#
# ==================================================
#
# Results for xai:
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': ' **', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': 'Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': '**.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220616, object='chat.completion.chunk')
# ChatCompletionChunk(id='c2e35645-d8c1-4834-9123-e62b4b855386', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='grok-beta', created=1734220616, object='chat.completion.chunk')
#
# ==================================================
#
# Results for anthropic:
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'The capital of France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is Paris.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n\nParis is locate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd in the north-central part', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' of the country an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd is the most', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' populous city in France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '. It is situate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd on the River', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Seine and is a', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' major global cultural', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', fashion', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', and cul', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'inary center,', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' renowned for its art', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', architecture', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', museums, an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd monuments', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '.\n\nSome', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' famous', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Parisian landmarks include', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ':\n\n1', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '. Eif', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'fel Tower', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n2.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Louvre Museum\n3', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '. Notre-Dame', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Cathedral\n4.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Arc de Triomp', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'he\n5.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Champs-', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'Élysées', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n\nParis', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' has been the French', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' capital since the ', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '12', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'th century and is', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' also an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' important center', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' for business, education', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', entertainment, and transportation', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' in Europe', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='message_complete', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant'}, finish_reason='end_turn')], model='', created=0, object='chat.completion.chunk')
#
# ==================================================
#
# Results for ollama:
# ChatCompletionChunk(id='33a2f82a-f07c-48e4-bdb5-a34da9e1b7e5', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='23883868-7831-472c-8726-c55d9225ac08', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='9d914bb1-c1b2-460b-ab37-bd2f4a8f1b90', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='edcdddd4-118f-48af-b6b4-5ea9ae83de63', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='c847970d-47eb-4fbc-82cc-cab59ef3ddd7', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='c447ecab-ba4f-49c8-bb7f-44ae96a41b01', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='13cf183b-494b-4aa5-af92-c24bdde7818c', choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='4b2f1c2d-2a7c-4d49-bd16-942f5823c9a0', choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='92d850c2-5117-4cc2-8a67-a674f47b1c28', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' 😊', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='bdf05386-de78-4a17-b4cd-b45f39ad3d58', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='ba183d09-3cb4-4b84-aa83-6e190590c4fd', choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n', role='assistant'), finish_reason=None)], model='gemma2', created=1734220622, object='chat.completion.chunk')
# ChatCompletionChunk(id='8d445e6d-2c4b-42c8-b3e2-2109843b83b3', choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant'), finish_reason='stop')], model='gemma2', created=1734220622, object='chat.completion.chunk')
#
# ==================================================
#
# Results for gemini:
# ChatCompletionChunk(id='gemini-chunk--986569404482458867', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant'), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734220623, object='chat.completion.chunk')
# ChatCompletionChunk(id='gemini-chunk--986569404482458867', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is Paris.\n', role='assistant'), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734220624, object='chat.completion.chunk')
#
# ==================================================

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = await llm.achat_complete(
        messages, stream=True
    )

    async for chunk in result:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' known', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' for', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' icon', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'ic', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' land', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'marks', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' like', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' E', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'iff', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'el', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Tower', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Lou', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'vre', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Museum', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Not', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 're', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'D', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'ame', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' Cat', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 'hedral', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' also', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' largest', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' city', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' in', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734220625-u8wxBrFXGF9PDGWxqr9m', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734220625, object='chat.completion.chunk')
#
# ==================================================
#
# Results for openai:
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': '.', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AeWINqExiYfpSN9M4h2pMvUxYatwa', choices=[StreamChoice(index=0, delta={'content': None, 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='gpt-4o-2024-08-06', created=1734220627, object='chat.completion.chunk')
#
# ==================================================
#
# Results for xai:
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220628, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220628, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220628, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220629, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220629, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': ' **', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220629, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': 'Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220629, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': '**.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734220629, object='chat.completion.chunk')
# ChatCompletionChunk(id='2bcb409b-b36a-4535-b1f4-db68edd57d6f', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='grok-beta', created=1734220629, object='chat.completion.chunk')
#
# ==================================================
#
# Results for anthropic:
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'The capital of France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is Paris.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n\nParis', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is locate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd in the north', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'central part of the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' country an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd is the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' most', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' populous city in France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '. It is situate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd on the River', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Seine and is a', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' major cultural, commercial', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', fashion', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', and cul', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'inary center,', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' famous', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' for its art', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' architecture, museums', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', and monuments', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' like', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' the Eif', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'fel Tower, the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Louvre,', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' and Notre-', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'Dame Cathedral.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Paris has been', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' French', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' capital since the ', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '12', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'th century and is', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' also', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' the seat', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' of the French government', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='message_complete', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant'}, finish_reason='end_turn')], model='', created=0, object='chat.completion.chunk')
#
# ==================================================
#
# Results for ollama:
# ChatCompletionChunk(id='b0d34909-5c6e-44f1-8183-d1ad853f4f48', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='101db0fa-55b2-4153-9fd8-c707148fbb9f', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='a8e237fb-4717-4ad1-b585-afb9bd02d7ab', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='7e774346-da79-4356-b30a-a14847d6ca61', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='4007748c-6aa3-4cf9-9d1f-743fe198ac16', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='451689c2-2a69-4252-94f9-aab2fc3b1f8d', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='3c8535f7-6172-4f3a-908c-f6206837f1c5', choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='95e08ece-4403-43ed-8c1d-2165900a7814', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='1ac4aadf-7c2c-478f-a3ba-44d9449c2031', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🇫', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='9c376ed3-48e3-4ba9-be5b-3628afb52fd5', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🇷', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='a4691c30-2ac6-4c33-b3d2-491c6c1b037c', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='298a66c5-c5bc-4972-9722-ac14aa38011e', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🗼', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='2d694148-030d-4535-9cc7-99fa2947de8c', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='ed0a7267-c9c2-469b-8549-8baef0eb326e', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🥖', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='7bb4ae4d-d88b-4dd9-a3a4-3f2a78676b84', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='0dfd7260-cd3e-47fa-85fa-e167018936a8', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🍷', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='17e248ba-875f-41fa-9513-e57bf7274a46', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='c67c9e30-72a4-4dbf-8b2a-f29ec3b35fd5', choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n\n\n', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='3a6fcef0-c24b-4d60-88d0-629f5c035cf7', choices=[StreamChoice(index=0, delta=DeltaMessage(content='Is', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='99cf5a3f-2d41-4cff-a4d3-42f0b568283e', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' there', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='7b2d4e25-92d9-4c24-8061-be4655c3f2e9', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' anything', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='13602bdf-dfd7-4d1a-8849-b9f4cb368cdf', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' else', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='6189184f-987d-45cf-aba0-0be24452daa8', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' I', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='e26a831b-07ba-4499-932b-c2830411f30f', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' can', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='4a216347-4335-44f1-819d-ccaa87f7031d', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' help', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='9fe28330-2722-458a-9f22-01a995fdc19e', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' you', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='ea557e36-20a4-476f-bfb1-d9186c229685', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' with', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='ae0cf6c3-ebc9-449e-9510-9a76146f3572', choices=[StreamChoice(index=0, delta=DeltaMessage(content='?', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='5285b5ec-4579-404b-8152-896e84892d05', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' 😊', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='5b13f03c-4c6c-4dbd-be78-7d7fc25cd08e', choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n', role='assistant'), finish_reason=None)], model='gemma2', created=1734220633, object='chat.completion.chunk')
# ChatCompletionChunk(id='d3898df8-9b4c-4c17-bb75-f6b051afba67', choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant'), finish_reason='stop')], model='gemma2', created=1734220633, object='chat.completion.chunk')
#
# ==================================================
#
# Results for gemini:
# ChatCompletionChunk(id='gemini-chunk--986569404482458867', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant'), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734220634, object='chat.completion.chunk')
# ChatCompletionChunk(id='gemini-chunk--986569404482458867', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is Paris.\n', role='assistant'), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734220634, object='chat.completion.chunk')
#
# ==================================================

# %% [markdown]
# ## LangChain

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.invoke(messages)
    print(response.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France. If you have any other questions about France or anything else, feel free to ask!
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**. 🇫🇷
#
#
# ==================================================
#
# Results for gemini:
# The capital of France is **Paris**.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = await model.ainvoke(messages)
    print(response.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# Paris is located in the north-central part of the country and is the most populous city in France. It is situated on the River Seine and is a major global cultural, fashion, and culinary center known for its art, architecture, and landmarks like the Eiffel Tower, the Louvre Museum, and the Notre-Dame Cathedral.
#
# Paris has been the French capital since the 12th century and is also the political and commercial heart of the nation. It is the seat of the French government and home to many international organizations, including the OECD and UNESCO.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**. 🇫🇷
#
#
# ==================================================
#
# Results for gemini:
# The capital of France is **Paris**.
#
#
# ==================================================

# %% [markdown]
# ### Streaming

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"], streaming=True)
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.stream(messages)
    for chunk in response:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# content='' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='The' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' capital' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' of' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' France' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' is' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='.' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' It' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content="'" additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='s' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' known' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' for' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' icon' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='ic' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' land' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='marks' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' like' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' the' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' E' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='iff' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='el' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Tower' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=',' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' the' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Lou' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='vre' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Museum' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=',' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' and' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Not' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='re' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='-' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='D' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='ame' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' Cat' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='hedral' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='.' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' It' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content="'" additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='s' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' also' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' the' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' largest' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' city' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' in' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content=' France' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='.' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'mistralai/mistral-large-2411'} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e'
# content='' additional_kwargs={} response_metadata={} id='run-9db4870a-3812-468c-b186-d2a8dd46b07e' usage_metadata={'input_tokens': 19, 'output_tokens': 47, 'total_tokens': 66, 'input_token_details': {}, 'output_token_details': {}}
#
# ==================================================
#
# Results for openai:
# content='' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content='The' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content=' capital' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content=' of' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content=' France' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content=' is' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content='.' additional_kwargs={} response_metadata={} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9faba9f038'} id='run-d2fc4e44-a5da-44e2-accc-d2ab24848536'
#
# ==================================================
#
# Results for xai:
# content='The' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 1, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' capital' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 2, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' of' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 3, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' France' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 4, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' is' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 5, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' **' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='Paris' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 7, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='**.' additional_kwargs={} response_metadata={} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 8, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'grok-beta', 'system_fingerprint': 'fp_a019526223'} id='run-8bd43ae9-3700-41d7-82e5-6a6812c1ede2' usage_metadata={'input_tokens': 23, 'output_tokens': 9, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
#
# ==================================================
#
# Results for anthropic:
# content='' additional_kwargs={} response_metadata={} id='run-47ee708b-cc74-46df-b3f7-5958ee3c09bd' usage_metadata={'input_tokens': 20, 'output_tokens': 3, 'total_tokens': 23, 'input_token_details': {}}
# content='The capital of' additional_kwargs={} response_metadata={} id='run-47ee708b-cc74-46df-b3f7-5958ee3c09bd'
# content=' France is Paris.' additional_kwargs={} response_metadata={} id='run-47ee708b-cc74-46df-b3f7-5958ee3c09bd'
# content='' additional_kwargs={} response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None} id='run-47ee708b-cc74-46df-b3f7-5958ee3c09bd' usage_metadata={'input_tokens': 0, 'output_tokens': 10, 'total_tokens': 10, 'input_token_details': {}}
#
# ==================================================
#
# Results for ollama:
# content='The' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' capital' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' of' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' France' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' is' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='.' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='  ' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='🇫' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='🇷' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content=' ' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='🗼' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='  ' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='\n' additional_kwargs={} response_metadata={} id='run-29e9e379-b933-4099-9ff6-2000f6af5853'
# content='' additional_kwargs={} response_metadata={'model': 'gemma2', 'created_at': '2024-12-14T23:57:38.856063286Z', 'done': True, 'done_reason': 'stop', 'total_duration': 180362833, 'load_duration': 23626713, 'prompt_eval_count': 23, 'prompt_eval_duration': 4000000, 'eval_count': 15, 'eval_duration': 151000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)} id='run-29e9e379-b933-4099-9ff6-2000f6af5853' usage_metadata={'input_tokens': 23, 'output_tokens': 15, 'total_tokens': 38}
#
# ==================================================
#
# Results for gemini:
# content='The' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-deaea71e-48c7-4aa5-81b2-6e1390bbe1f4' usage_metadata={'input_tokens': 15, 'output_tokens': 0, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}}
# content=' capital of France is **Paris**.\n' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-deaea71e-48c7-4aa5-81b2-6e1390bbe1f4' usage_metadata={'input_tokens': 0, 'output_tokens': 9, 'total_tokens': 9, 'input_token_details': {'cache_read': 0}}
#
# ==================================================

# %% [markdown]
# ### Asynchronous Streaming

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"], streaming=True)
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.astream(messages)
    async for chunk in response:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# content='' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='The' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' capital' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' of' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' France' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' is' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='.' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' It' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content="'" additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='s' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' known' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' for' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' icon' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='ic' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' land' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='marks' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' like' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' the' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' E' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='iff' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='el' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Tower' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=',' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' the' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Lou' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='vre' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Museum' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=',' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' and' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Not' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='re' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='-' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='D' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='ame' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' Cat' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='hedral' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='.' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' It' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content="'" additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='s' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' also' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' the' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' largest' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' city' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' in' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content=' France' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='.' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'mistralai/mistral-large-2411'} id='run-9c515483-3688-44d4-a468-26657b1e98e2'
# content='' additional_kwargs={} response_metadata={} id='run-9c515483-3688-44d4-a468-26657b1e98e2' usage_metadata={'input_tokens': 19, 'output_tokens': 47, 'total_tokens': 66, 'input_token_details': {}, 'output_token_details': {}}
#
# ==================================================
#
# Results for openai:
# content='' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content='The' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content=' capital' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content=' of' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content=' France' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content=' is' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content='.' additional_kwargs={} response_metadata={} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_90354628f2'} id='run-789c4112-d2b9-4b79-98d0-d04ca975b9c5'
#
# ==================================================
#
# Results for xai:
# content='The' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 1, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' capital' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 2, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' of' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 3, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' France' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 4, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' is' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 5, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' **' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='Paris' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 7, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='**.' additional_kwargs={} response_metadata={} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 8, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'grok-beta', 'system_fingerprint': 'fp_a019526223'} id='run-6b04a6d5-c167-4811-a075-0bd93b88173c' usage_metadata={'input_tokens': 23, 'output_tokens': 9, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
#
# ==================================================
#
# Results for anthropic:
# content='' additional_kwargs={} response_metadata={} id='run-287d5a2d-9c86-4e5f-82b2-a28aa84c57bc' usage_metadata={'input_tokens': 20, 'output_tokens': 4, 'total_tokens': 24, 'input_token_details': {}}
# content='The capital of France' additional_kwargs={} response_metadata={} id='run-287d5a2d-9c86-4e5f-82b2-a28aa84c57bc'
# content=' is Paris.' additional_kwargs={} response_metadata={} id='run-287d5a2d-9c86-4e5f-82b2-a28aa84c57bc'
# content='' additional_kwargs={} response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None} id='run-287d5a2d-9c86-4e5f-82b2-a28aa84c57bc' usage_metadata={'input_tokens': 0, 'output_tokens': 10, 'total_tokens': 10, 'input_token_details': {}}
#
# ==================================================
#
# Results for ollama:
# content='The' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' capital' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' of' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' France' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' is' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' **' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content='Paris' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content='**.' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content=' 😊' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content='  ' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content='\n' additional_kwargs={} response_metadata={} id='run-7629f165-7f01-4cc8-8206-73177d85dd63'
# content='' additional_kwargs={} response_metadata={'model': 'gemma2', 'created_at': '2024-12-14T23:57:45.812220349Z', 'done': True, 'done_reason': 'stop', 'total_duration': 154280083, 'load_duration': 22760971, 'prompt_eval_count': 23, 'prompt_eval_duration': 7000000, 'eval_count': 12, 'eval_duration': 123000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)} id='run-7629f165-7f01-4cc8-8206-73177d85dd63' usage_metadata={'input_tokens': 23, 'output_tokens': 12, 'total_tokens': 35}
#
# ==================================================
#
# Results for gemini:
# content='The' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-aaa180ac-8f20-4f33-9d24-1c5e5c2d730e' usage_metadata={'input_tokens': 15, 'output_tokens': 0, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}}
# content=' capital of France is **Paris**.\n' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-aaa180ac-8f20-4f33-9d24-1c5e5c2d730e' usage_metadata={'input_tokens': 0, 'output_tokens': 9, 'total_tokens': 9, 'input_token_details': {'cache_read': 0}}
#
# ==================================================
